# %%
c= "this is a string"
print(type(c))
# Out:
# <class 'str'>

# %%
# bool类型
d = True   # 1
e = False  # 0

a = 12

# %%
print(a)
# Out:
# 12

# %%
print(c  +  "!" )
# Out:
# this is a string!

# %%
a = 12
b = float(a)
print(type(b))
# Out:
# <class 'float'>

# %%
a = 12/5
print(a)
# Out:
# 2.4

# %%
a = 12//5
print(a)
# Out:
# 2

# %%
print(14//5)
# Out:
# 2

# %%
print(12%5)
# Out:
# 2

# %%
print(14%5)
# Out:
# 4

# %%
# if语句
print(1>5)
print(1>=5)
print(bool(1))
print(bool(0))
# Out:
# False
# False
# True
# False

# %%
a = 1
  #  a 不等于1    a != 1
if (a==1):
    print("a is 1")
elif  (a ==2):
    print("a is 2")
elif (a ==3):
    print("a is 3")
elif (a==4):
    print("a is 4")
else :
    print("a is other")
# Out:
# b is greater than a

# %%
# while  语句
a = 0
while (a<5):
    print(a)
    a = a+1

# %%
#  range
print(range(5))
# Out:
# range(0, 5)

# %%
for i in  range(5):
    print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
#  list
list1 = [1,2,3,4,5]
print(list1[0])
print(list1[1])
# Out:
# 1
# 2
