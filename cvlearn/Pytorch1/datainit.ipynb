# %% [markdown]
# 创建一个人工数据集，并存储在csv（逗号分隔值）文件

# %%
import os

os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n')
    f.write('NA,Pave,127500\n')
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
import pandas as pd

data = pd.read_csv(data_file)
print(data)
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
import numpy as np


old_mean = pd.DataFrame.mean
pd.DataFrame.mean = lambda self, *args, **kwargs: old_mean(self.select_dtypes(include=[np.number]), *args, **kwargs)


inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
inputs = inputs.fillna(inputs.mean())
print(inputs)
# Out:
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na=True)
inputs  = inputs.astype(int)
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0         3           1          0
# 1         2           0          1
# 2         4           0          1
# 3         3           0          1

# %%
import torch

X, y = torch.tensor(inputs.values,dtype=torch.float64), torch.tensor(outputs.values)
X, y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([127500, 106000, 178100, 140000]))
